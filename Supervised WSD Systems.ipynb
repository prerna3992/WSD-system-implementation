# %% [markdown]
# # Problem 3:

# %% [markdown]
# ## 2. Supervised WSD Systems

# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
from nltk.stem import PorterStemmer
porter = PorterStemmer()

# %%
train_dt=open("P:/Fall 18/Text Mining/Homework02/train.data","r")
validate_dt=open("P:/Fall 18/Text Mining/Homework02/validate.data","r")
dict_dt=open("P:/Fall 18/Text Mining/Homework02/dictionary.xml","r")

# %%
dict_parse=BeautifulSoup(dict_dt,'xml')

# %%
dictt_gloss={}
for i in dict_parse.find_all("lexelt"): 
    x=(i.get('item'))
    for j in i.find_all("sense"):        
        z = j.get('id')
        y=(j.get('gloss'))
        print(x,y)
        dictt_gloss.setdefault(x,[]).append(y)

print(dictt_gloss)
# Out:
# begin.v start, have an initial point
# begin.v initiate an undertaking
# begin.v make a locution, speak
# begin.v partially attain
# begin.v express feelings of pain, dissatisfaction, or resentment
# begin.v make formal, legal accusation or bring charge
# begin.v a building, or group of buildings, for industrial activity
# begin.v living photosynthesizing organism
# begin.v a contrivance or stratagem
# begin.v must have, demand
# begin.v must do something
# begin.v an employee who delivers things, e.g. mail
# begin.v a bearer who bodily conveys something, e.g, supplies
# begin.v a vehicle or vessel that transports cargo or passengers
# begin.v a naval warship bearing aircraft
# begin.v a device to hold or transport items
# begin.v a transportation business
# begin.v an insurance business
# begin.v a telecommunications business
# begin.v an organism carrying a masked recessive gene
# begin.v an organism carrying a pathogen, but not showing symptoms
# begin.v inactive chemical substance acting as a catalyst
# begin.v a particle holding, or capable of holding, electric charge
# begin.v a modulated radio wave that can convey a signal
# begin.v happen or take place
# begin.v come to mind
# begin.v exist, be present
# begin.v happen or go together
# begin.v nation
# begin.v one of the constituent administrative districts of a nation
# begin.v the conditions and attributes that define something
# begin.v U.S. Dept. of State
# begin.v make known, declare
# begin.v name, identify
# begin.v foretell
# begin.v consider as important enough for attention, concern or liking
# begin.v tend or supervise somebody, provide protection and assistance
# begin.v want, desire or perfer to do something
# begin.v inquire, seek an answer
# begin.v request or demand something from someone
# begin.v specify a price or value for something
# begin.v need, call for
# begin.v acting in a manner that results in specific consequences
# begin.v invite
# begin.v an argument that gives grounds or justification for a position
# begin.v action serving a protective function, often military
# begin.v a sports team in the role of preventing scoring by the opponent
# begin.v a legal team serving the client against the prosecution
# begin.v a structure to withstand attack
# begin.v organization of defenders, as military units
# begin.v business enterprises that build, develop military weaponry
# begin.v a federal department responsible for safeguarding national security
# begin.v available wealth or assets
# begin.v a seat of government or influence
# begin.v a letter represented in uppercase
# begin.v a book by Karl Marx
# begin.v uppermost part of a column
# begin.v residence change
# begin.v action
# begin.v Game:a turn
# begin.v other moves
# begin.v limit
# begin.v bottom
# begin.v foundation
# begin.v principle ingredient
# begin.v alkali
# begin.v bag
# begin.v station
# begin.v infrastructure
# begin.v stem
# begin.v radix
# begin.v transistor piece
# begin.v al-Qaeda
# begin.v a portion or percentage of a whole
# begin.v capital stock in a corporation
# begin.v a tool for tilling soil
# begin.v give, provide, donate something
# begin.v be a factor, play a role in
# begin.v induce, make happen
# begin.v process or set of rules that provides order and structure
# begin.v man-made system of (electrical/mechanical) closely interacting parts
# begin.v biological system of closely interacting parts
# begin.v loose collection of concrete objects which are linked through regularized interactions
# begin.v the powers that be
# begin.v strong desires and feelings
# begin.v a sample of matter in which substances in different phases are in equilibrium.
# begin.v repair,mend
# begin.v fasten,secure
# begin.v specify
# begin.v prepare, make, get ready
# begin.v take revenge on
# begin.v sterilize
# begin.v keep away, prevent from happening, or not do something
# begin.v LAW- annul, make void, make invalid
# begin.v relish, savor, delight in
# begin.v derive benefit from
# begin.v reveal something previously secret
# begin.v expose by removing a cover
# begin.v (cause to) change orientation or direction
# begin.v (cause to) undergo a transformation of substance, shape, or feature
# begin.v (cause to) undergo a change in attitude, emotion, belief, or custom
# begin.v send away or reject
# begin.v change the activation or arousal of
# begin.v prove, show to be, end up
# begin.v appear, discover, find
# begin.v produce, especially through commerce or business
# begin.v shape by rotating
# begin.v sprain, hurt by twisting
# begin.v deliver, hand over
# begin.v go to or get up from sleep
# begin.v (cause to) improve
# begin.v come or gather
# begin.v idioms
# begin.v perceive by sight
# begin.v realize, visualize or understand mentally (or through imagination)
# begin.v witness, observe, or experience
# begin.v verify, prove, check or insure by actively examining (evidence)
# begin.v take care of, take responsilibity over, keep up with
# begin.v meet or encounter on social or professional capacity
# begin.v match as in poker game
# begin.v SEE RED-become angry or upset
# begin.v SEE THE LIGHT-change or reform for the bettter
# begin.v SEE EYE TO EYE-be in agreement
# begin.v result in, tend to, cause, conduce
# begin.v travel in front of, be first, precede
# begin.v extend, connect, afford access to
# begin.v head, preside, direct
# begin.v guide
# begin.v pass, spend
# begin.v run, place
# begin.v origin or beginning
# begin.v an information reference, e.g. publication or an organization
# begin.v an informant
# begin.v the cause or instigation of something
# begin.v inspiration or muse
# begin.v repository or reservoir of something
# begin.v changing one thing for another
# begin.v a mutual expression of views
# begin.v marketplace
# begin.v telecommunications facility
# begin.v changing money, collectively
# begin.v a rally
# begin.v the physical expanse of the universe
# begin.v size or extent of an area or location, bounded or demarcated
# begin.v mathematical dimensionality, geometry
# begin.v small purposefully blank regions in documents
# begin.v unrestricted assertion of personal identity
# begin.v an amount or interval of time
# begin.v a notation, a single blank between letters
# begin.v block of typeset with no raised letters
# begin.v command
# begin.v order of magnitude
# begin.v lawfulness
# begin.v arrangement
# begin.v neatness
# begin.v purchase
# begin.v club
# begin.v taxonomic group
# begin.v greek style
# begin.v take something or someone away from somewhere
# begin.v murder
# begin.v maintain or preserve a particular condition, state, or activity
# begin.v retain ownership, access or title to something
# begin.v cause to stay in place; retain something in a particular place
# begin.v restrain, hold back, or prevent from doing something
# begin.v conform to, honor
# begin.v care for, sustain, look after
# begin.v observe, follow along, synchronize, track
# begin.v multi-word and verb particle constructions
# begin.v a system of interconnected social entities,e.g., people, organizations
# begin.v a broadcasting business, an enterprise that disseminates content via telecommunications equipment
# begin.v a physical system of interconnected components
# begin.v a mesh-like fabric or substance
# begin.v buy, obtain via finacncial transaction
# begin.v act, engage in, undertake, execute, cause, make
# begin.v fare, get along
# begin.v suffice or satisfy
# begin.v serve time (usually in prison)
# begin.v manage, carry on
# begin.v travel or go
# begin.v move, travel, proceed
# begin.v depart
# begin.v die, cease to function
# begin.v change to or continue in a certain state
# begin.v happen
# begin.v say or have the (sound) sequence of
# begin.v be on the point of; be intending to
# begin.v belong, fit, harmonize
# begin.v attend
# begin.v extend or stretch
# begin.v function, operate
# begin.v rifle, search through
# begin.v give support to
# begin.v miscellaneous idioms
# begin.v obtain, incur, get, encounter
# begin.v welcome, invite, accept
# begin.v stop, finish, terminate (A ends)
# begin.v bring to a halt, terminate (A causes B to end)
# begin.v be the end of, conclude (A is the event at the end of B)
# begin.v end up, wind up, finally be or do something
# begin.v have an initial point with some characteristic
# begin.v begin an event, action, or effect
# begin.v to cause to come into being
# begin.v (cause a machine to) begin to function or operate
# begin.v begin a journey, depart
# begin.v play in the starting lineup
# begin.v startle, jump
# begin.v portion
# begin.v our/his/my part
# begin.v function
# begin.v theatrical role
# begin.v share
# begin.v voice
# begin.v divide in hair
# begin.v try to do something
# begin.v the act of surmounting, climbing, descending
# begin.v experience, sense
# begin.v touch,grope
# begin.v find, conclude
# begin.v approximate, guess, reckon
# begin.v put, place, position
# begin.v go down, sink
# begin.v determine, fix at certain value
# begin.v prepare, arrange; create or organize for a particular purpose
# begin.v cause to assume a condition
# begin.v begin an activity, or cause one to begin
# begin.v fix firmly, solidify
# begin.v ensnare, frame, arrange through deceit
# begin.v dialect for SIT
# begin.v (cause to) attack
# begin.v hone
# begin.v reproduce,fructify
# begin.v move, travel, arrive
# begin.v occur, happen
# begin.v progress to a state
# begin.v be available, exist in a state
# begin.v originate from, issue from
# begin.v occur in a sequence, prioritized
# begin.v reach, extend to, total
# begin.v discover or think up
# begin.v be revealed
# begin.v experience orgasm
# begin.v idioms
# begin.v yield, create, make
# begin.v exhibit, release
# begin.v develop, acquire
# begin.v change for the better
# begin.v an opportunity
# begin.v events without apparent cause, random occurrence, luck
# begin.v risk, potential bad outcome
# begin.v a measure of the likelihood or probability of an event
# begin.v maintain or affirm that something is true
# begin.v demand, ask for, or take as one's due
# begin.v deserve, call for, or require
# begin.v cause death, as if by right
# begin.v increase
# begin.v lift, elevate, orient upwards
# begin.v express, activate
# begin.v collect, levy
# begin.v cultivate, nurture
# begin.v invoke, elicit, set off
# begin.v advance, better, promote
# begin.v construct, build
# begin.v end
# begin.v quality
# begin.v quantity
# begin.v moral principal
# begin.v duration of a musical note
# begin.v relative darkness
# begin.v consider, believe
# begin.v look
# begin.v concern, pertain
# begin.v finish an activity or process, either physical or abstract
# begin.v carry out an assigned task or duty
# begin.v make whole, add a missing part to a given whole
# begin.v establish the truth, validity, or authenticity of something
# begin.v turn out to be, show a particular result after a period of time
# begin.v show oneself to be competent or worthy
# begin.v LAW- establish as authentic or genuine
# begin.v COOKING- rise or gain volume in a warm place
# begin.v PRINTING ARTS- make a test impression
# begin.v cost
# begin.v pace, speed
# begin.v time to come
# begin.v verb tense
# begin.v commodities
# begin.v personal time to come
# begin.v use something to acquire goods; obtain through trade or transaction
# begin.v bribe, make payments to in exchange for benefits
# begin.v accept as true
# begin.v invest
# begin.v be killed; die
# begin.v take over ownership of
# begin.v stall, delay
# begin.v pledge or make a commitment
# begin.v give grounds for expectation
# begin.v a written list of particular things being offered
# begin.v a written notice that announces or advertises something
# begin.v a statute or draft not yet become law
# begin.v an itemized statement of money owed
# begin.v a printed note that is legal tender
# begin.v the mouth of a bird
# begin.v a long-handled saw
# begin.v brim of a hat that projects forward, visor
# begin.v the point of a ship anchor's fluke
# begin.v physically construct something, either directly or by implication
# begin.v develop, increase
# begin.v establish or create a complex process or abstract entity, according to a plan
# begin.v improve cleaning action of
# begin.v authorize, pass, clear
# begin.v judge or regard favorably
# begin.v power to give orders, official state of power
# begin.v assurance, confidence
# begin.v officials who have specific powers
# begin.v most knowledgable source, expert
# begin.v a government agency with specific power
# begin.v official permission to do something
# begin.v remember, cause to remember
# begin.v remove from circulation, defective products
# begin.v summon or order someone back
# begin.v restore or revive
# begin.v Medicines
# begin.v Narcotics
# begin.v Senses 1 and 2
# begin.v exert oneself in an activity
# begin.v perform, function, behave
# begin.v shape, form, handle
# begin.v proceed, move, position
# begin.v control, exploit, act upon
# begin.v operate
# begin.v ferment
# begin.v solve, figure out
# begin.v idioms
# begin.v a plan of action, approach
# begin.v Insurance policy
# begin.v an illegal lottery or numbers game
# begin.v an ability to control or influence
# begin.v entity that possesses ability to control or influence
# begin.v exerted physical force
# begin.v a mathematical measurement
# begin.v substitute, switch or supplant
# begin.v restore or return
# begin.v locate, discover, or encounter
# begin.v solve or calculate
# begin.v opine or believe
# begin.v accumulate a resource
# begin.v rule or pronounce, usually legal
# begin.v blame, criticize
# begin.v a general reference to any group of humans
# begin.v ordinary citizenry without special rank or status
# begin.v family line, relatives
# begin.v subordinate work associates
# begin.v specific ethnic groups
# begin.v state prosecution in a trial
# begin.v describe, account
# begin.v inform on
# begin.v be accountable to
# begin.v report out
# begin.v dot
# begin.v location
# begin.v meaning
# begin.v detail
# begin.v degree, level, stage
# begin.v sharp tip
# begin.v game scoring
# begin.v cape
# begin.v punctuation mark
# begin.v point
# begin.v gunpoint
# begin.v wall socket
# begin.v breaker point
# begin.v fraction
# begin.v have an effect or impact on
# begin.v give an impression
# begin.v take on an appearance or position
# begin.v desire, wish, plan, intend
# begin.v physically grasp, position, or support something
# begin.v stop or restrain something; keep something from being used
# begin.v maintain one's state, position, or physical integrity
# begin.v maintain an attitude, belief, or opinion
# begin.v possess or control something, e.g., money, position of authority, honor
# begin.v contain or accommodate
# begin.v be relevant or applicable
# begin.v conduct a social event
# begin.v block or cover protectively (by grasping)
# begin.v idioms
# begin.v paid position
# begin.v task
# begin.v being at work
# begin.v object being worked on
# begin.v a difficulty
# begin.v destruction
# begin.v robbery
# begin.v Biblical figure
# begin.v Biblical book
# begin.v computer program
# begin.v clarify, make comprehensible, describe
# begin.v be a reason, cause, or justification of
# begin.v give an account or convey impression of
# begin.v depict or represent something pictorially
# begin.v trace the form or outline of
# begin.v consequence
# begin.v general impression
# begin.v validity
# begin.v theme
# begin.v property
# begin.v the process
# begin.v the end product
# begin.v the act of developing
# begin.v spatial location or placement of something/someone
# begin.v opinion, attitude, stance, point of view, assumption
# begin.v context, situation or circumstance
# begin.v financial holdings of an investor, a financial market commitment
# begin.v profession, job, function includes position in team sports)
# begin.v rank in a sequence, standing in relation to others
# begin.v a posture or arrangement, usually intentional
# begin.v let, make possible, give permission
# begin.v provide for, allot
# begin.v to put together, assemble, concoct
# begin.v to make ready, fit out
# begin.v overseeing or directing
# begin.v the people in charge
# begin.v convey, show, state in some form
# begin.v press out physically
# begin.v to mail or post something via a rapid method
# begin.v move forward, act at speed, pelt along
# begin.v make someone or something hasten, induce or stimulate
# begin.v run with a ball
# begin.v meet or get to know members of fraternity or sorority
# begin.v be
# begin.v subsist, survive
# begin.v give permission or privilege, bestow officially as judged due
# begin.v willing to admit as truth
# begin.v relinquish (physical) control
# begin.v cause death, be fatal
# begin.v cause great pain or anguish
# begin.v eliminate
# begin.v thwart
# begin.v overwhelm
# begin.v to strain oneself to the limit
# begin.v cease operation of
# begin.v hit with great force
# begin.v drink down
# begin.v put forward for consideration
# begin.v intend
# begin.v ask for hand in marriage
# begin.v Geographic region
# begin.v social sphere, scope of activity or interest
# begin.v a circumscribed place with a specific characteristic
# begin.v 2D bounded space in geometry
# begin.v field of study, knowledge domain
# begin.v recall to mind or keep in mind a piece of information
# begin.v exercise or have power of memory
# begin.v commemorate a special person, event, or occasion
# begin.v consider, include
# begin.v give greetings from
# begin.v recover one's good manners after behaving badly
# begin.v study, investigate, or analyze in detail
# begin.v inspect something or somebody/look at
# begin.v test someone by questioning; interrogate
# begin.v an agent expresses or communicates a concept through words
# begin.v to indicate something through a physical, non-verbal medium
# begin.v express a supposition, occurs with the expression 'let us'
# begin.v a written document's specific wording
# begin.v physical act of articulating or pronouncing speech sounds
# begin.v connect, link or unite separate things, either physically or abstractly
# begin.v enlist or accept membership within some group or organization
# begin.v participate with someone else in some event
# begin.v accompany or meet up
# begin.v discuss terms of agreement
# begin.v navigate or manage something successfully
# begin.v sell or transfer ownership
# begin.v hold in a given state or situation
# begin.v assert a proposition or belief
# begin.v keep a reocrd
# begin.v provide care and sustenance for someone
# begin.v state
# begin.v stipulation
# begin.v consideration
# begin.v not the control
# begin.v accept something as true or probable, based on evidence and reasoning.
# begin.v accept a doctrine, not necessarily nn the basis of reason or logic
# begin.v 60 minutes
# begin.v time of day
# begin.v memorable period
# begin.v distance
# begin.v chair
# begin.v head of a country
# begin.v head of U.S.
# complain.v express feelings of pain, dissatisfaction, or resentment
# complain.v make formal, legal accusation or bring charge
# plant.n a building, or group of buildings, for industrial activity
# plant.n living photosynthesizing organism
# plant.n a contrivance or stratagem
# need.v must have, demand
# need.v must do something
# carrier.n an employee who delivers things, e.g. mail
# carrier.n a bearer who bodily conveys something, e.g, supplies
# carrier.n a vehicle or vessel that transports cargo or passengers
# carrier.n a naval warship bearing aircraft
# carrier.n a device to hold or transport items
# carrier.n a transportation business
# carrier.n an insurance business
# carrier.n a telecommunications business
# carrier.n an organism carrying a masked recessive gene
# carrier.n an organism carrying a pathogen, but not showing symptoms
# carrier.n inactive chemical substance acting as a catalyst
# carrier.n a particle holding, or capable of holding, electric charge
# carrier.n a modulated radio wave that can convey a signal
# occur.v happen or take place
# occur.v come to mind
# occur.v exist, be present
# occur.v happen or go together
# state.n nation
# state.n one of the constituent administrative districts of a nation
# state.n the conditions and attributes that define something
# state.n U.S. Dept. of State
# state.n make known, declare
# state.n name, identify
# state.n foretell
# state.n consider as important enough for attention, concern or liking
# state.n tend or supervise somebody, provide protection and assistance
# state.n want, desire or perfer to do something
# state.n inquire, seek an answer
# state.n request or demand something from someone
# state.n specify a price or value for something
# state.n need, call for
# state.n acting in a manner that results in specific consequences
# state.n invite
# state.n an argument that gives grounds or justification for a position
# state.n action serving a protective function, often military
# state.n a sports team in the role of preventing scoring by the opponent
# state.n a legal team serving the client against the prosecution
# state.n a structure to withstand attack
# state.n organization of defenders, as military units
# state.n business enterprises that build, develop military weaponry
# state.n a federal department responsible for safeguarding national security
# state.n available wealth or assets
# state.n a seat of government or influence
# state.n a letter represented in uppercase
# state.n a book by Karl Marx
# state.n uppermost part of a column
# state.n residence change
# state.n action
# state.n Game:a turn
# state.n other moves
# state.n limit
# state.n bottom
# state.n foundation
# state.n principle ingredient
# state.n alkali
# state.n bag
# state.n station
# state.n infrastructure
# state.n stem
# state.n radix
# state.n transistor piece
# state.n al-Qaeda
# state.n a portion or percentage of a whole
# state.n capital stock in a corporation
# state.n a tool for tilling soil
# state.n give, provide, donate something
# state.n be a factor, play a role in
# state.n induce, make happen
# state.n process or set of rules that provides order and structure
# state.n man-made system of (electrical/mechanical) closely interacting parts
# state.n biological system of closely interacting parts
# state.n loose collection of concrete objects which are linked through regularized interactions
# state.n the powers that be
# state.n strong desires and feelings
# state.n a sample of matter in which substances in different phases are in equilibrium.
# state.n repair,mend
# state.n fasten,secure
# state.n specify
# state.n prepare, make, get ready
# state.n take revenge on
# state.n sterilize
# state.n keep away, prevent from happening, or not do something
# state.n LAW- annul, make void, make invalid
# state.n relish, savor, delight in
# state.n derive benefit from
# state.n reveal something previously secret
# state.n expose by removing a cover
# state.n (cause to) change orientation or direction
# state.n (cause to) undergo a transformation of substance, shape, or feature
# state.n (cause to) undergo a change in attitude, emotion, belief, or custom
# state.n send away or reject
# state.n change the activation or arousal of
# state.n prove, show to be, end up
# state.n appear, discover, find
# state.n produce, especially through commerce or business
# state.n shape by rotating
# state.n sprain, hurt by twisting
# state.n deliver, hand over
# state.n go to or get up from sleep
# state.n (cause to) improve
# state.n come or gather
# state.n idioms
# state.n perceive by sight
# state.n realize, visualize or understand mentally (or through imagination)
# state.n witness, observe, or experience
# state.n verify, prove, check or insure by actively examining (evidence)
# state.n take care of, take responsilibity over, keep up with
# state.n meet or encounter on social or professional capacity
# state.n match as in poker game
# state.n SEE RED-become angry or upset
# state.n SEE THE LIGHT-change or reform for the bettter
# state.n SEE EYE TO EYE-be in agreement
# state.n result in, tend to, cause, conduce
# state.n travel in front of, be first, precede
# state.n extend, connect, afford access to
# state.n head, preside, direct
# state.n guide
# state.n pass, spend
# state.n run, place
# state.n origin or beginning
# state.n an information reference, e.g. publication or an organization
# state.n an informant
# state.n the cause or instigation of something
# state.n inspiration or muse
# state.n repository or reservoir of something
# state.n changing one thing for another
# state.n a mutual expression of views
# state.n marketplace
# state.n telecommunications facility
# state.n changing money, collectively
# state.n a rally
# state.n the physical expanse of the universe
# state.n size or extent of an area or location, bounded or demarcated
# state.n mathematical dimensionality, geometry
# state.n small purposefully blank regions in documents
# state.n unrestricted assertion of personal identity
# state.n an amount or interval of time
# state.n a notation, a single blank between letters
# state.n block of typeset with no raised letters
# state.n command
# state.n order of magnitude
# state.n lawfulness
# state.n arrangement
# state.n neatness
# state.n purchase
# state.n club
# state.n taxonomic group
# state.n greek style
# state.n take something or someone away from somewhere
# state.n murder
# state.n maintain or preserve a particular condition, state, or activity
# state.n retain ownership, access or title to something
# state.n cause to stay in place; retain something in a particular place
# state.n restrain, hold back, or prevent from doing something
# state.n conform to, honor
# state.n care for, sustain, look after
# state.n observe, follow along, synchronize, track
# state.n multi-word and verb particle constructions
# state.n a system of interconnected social entities,e.g., people, organizations
# state.n a broadcasting business, an enterprise that disseminates content via telecommunications equipment
# state.n a physical system of interconnected components
# state.n a mesh-like fabric or substance
# state.n buy, obtain via finacncial transaction
# state.n act, engage in, undertake, execute, cause, make
# state.n fare, get along
# state.n suffice or satisfy
# state.n serve time (usually in prison)
# state.n manage, carry on
# state.n travel or go
# state.n move, travel, proceed
# state.n depart
# state.n die, cease to function
# state.n change to or continue in a certain state
# state.n happen
# state.n say or have the (sound) sequence of
# state.n be on the point of; be intending to
# state.n belong, fit, harmonize
# state.n attend
# state.n extend or stretch
# state.n function, operate
# state.n rifle, search through
# state.n give support to
# state.n miscellaneous idioms
# state.n obtain, incur, get, encounter
# state.n welcome, invite, accept
# state.n stop, finish, terminate (A ends)
# state.n bring to a halt, terminate (A causes B to end)
# state.n be the end of, conclude (A is the event at the end of B)
# state.n end up, wind up, finally be or do something
# state.n have an initial point with some characteristic
# state.n begin an event, action, or effect
# state.n to cause to come into being
# state.n (cause a machine to) begin to function or operate
# state.n begin a journey, depart
# state.n play in the starting lineup
# state.n startle, jump
# state.n portion
# state.n our/his/my part
# state.n function
# state.n theatrical role
# state.n share
# state.n voice
# state.n divide in hair
# state.n try to do something
# state.n the act of surmounting, climbing, descending
# state.n experience, sense
# state.n touch,grope
# state.n find, conclude
# state.n approximate, guess, reckon
# state.n put, place, position
# state.n go down, sink
# state.n determine, fix at certain value
# state.n prepare, arrange; create or organize for a particular purpose
# state.n cause to assume a condition
# state.n begin an activity, or cause one to begin
# state.n fix firmly, solidify
# state.n ensnare, frame, arrange through deceit
# state.n dialect for SIT
# state.n (cause to) attack
# state.n hone
# state.n reproduce,fructify
# state.n move, travel, arrive
# state.n occur, happen
# state.n progress to a state
# state.n be available, exist in a state
# state.n originate from, issue from
# state.n occur in a sequence, prioritized
# state.n reach, extend to, total
# state.n discover or think up
# state.n be revealed
# state.n experience orgasm
# state.n idioms
# state.n yield, create, make
# state.n exhibit, release
# state.n develop, acquire
# state.n change for the better
# state.n an opportunity
# state.n events without apparent cause, random occurrence, luck
# state.n risk, potential bad outcome
# state.n a measure of the likelihood or probability of an event
# state.n maintain or affirm that something is true
# state.n demand, ask for, or take as one's due
# state.n deserve, call for, or require
# state.n cause death, as if by right
# state.n increase
# state.n lift, elevate, orient upwards
# state.n express, activate
# state.n collect, levy
# state.n cultivate, nurture
# state.n invoke, elicit, set off
# state.n advance, better, promote
# state.n construct, build
# state.n end
# state.n quality
# state.n quantity
# state.n moral principal
# state.n duration of a musical note
# state.n relative darkness
# state.n consider, believe
# state.n look
# state.n concern, pertain
# state.n finish an activity or process, either physical or abstract
# state.n carry out an assigned task or duty
# state.n make whole, add a missing part to a given whole
# state.n establish the truth, validity, or authenticity of something
# state.n turn out to be, show a particular result after a period of time
# state.n show oneself to be competent or worthy
# state.n LAW- establish as authentic or genuine
# state.n COOKING- rise or gain volume in a warm place
# state.n PRINTING ARTS- make a test impression
# state.n cost
# state.n pace, speed
# state.n time to come
# state.n verb tense
# state.n commodities
# state.n personal time to come
# state.n use something to acquire goods; obtain through trade or transaction
# state.n bribe, make payments to in exchange for benefits
# state.n accept as true
# state.n invest
# state.n be killed; die
# state.n take over ownership of
# state.n stall, delay
# state.n pledge or make a commitment
# state.n give grounds for expectation
# state.n a written list of particular things being offered
# state.n a written notice that announces or advertises something
# state.n a statute or draft not yet become law
# state.n an itemized statement of money owed
# state.n a printed note that is legal tender
# state.n the mouth of a bird
# state.n a long-handled saw
# state.n brim of a hat that projects forward, visor
# state.n the point of a ship anchor's fluke
# state.n physically construct something, either directly or by implication
# state.n develop, increase
# state.n establish or create a complex process or abstract entity, according to a plan
# state.n improve cleaning action of
# state.n authorize, pass, clear
# state.n judge or regard favorably
# state.n power to give orders, official state of power
# state.n assurance, confidence
# state.n officials who have specific powers
# state.n most knowledgable source, expert
# state.n a government agency with specific power
# state.n official permission to do something
# state.n remember, cause to remember
# state.n remove from circulation, defective products
# state.n summon or order someone back
# state.n restore or revive
# state.n Medicines
# state.n Narcotics
# state.n Senses 1 and 2
# state.n exert oneself in an activity
# state.n perform, function, behave
# state.n shape, form, handle
# state.n proceed, move, position
# state.n control, exploit, act upon
# state.n operate
# state.n ferment
# state.n solve, figure out
# state.n idioms
# state.n a plan of action, approach
# state.n Insurance policy
# state.n an illegal lottery or numbers game
# state.n an ability to control or influence
# state.n entity that possesses ability to control or influence
# state.n exerted physical force
# state.n a mathematical measurement
# state.n substitute, switch or supplant
# state.n restore or return
# state.n locate, discover, or encounter
# state.n solve or calculate
# state.n opine or believe
# state.n accumulate a resource
# state.n rule or pronounce, usually legal
# state.n blame, criticize
# state.n a general reference to any group of humans
# state.n ordinary citizenry without special rank or status
# state.n family line, relatives
# state.n subordinate work associates
# state.n specific ethnic groups
# state.n state prosecution in a trial
# state.n describe, account
# state.n inform on
# state.n be accountable to
# state.n report out
# state.n dot
# state.n location
# state.n meaning
# state.n detail
# state.n degree, level, stage
# state.n sharp tip
# state.n game scoring
# state.n cape
# state.n punctuation mark
# state.n point
# state.n gunpoint
# state.n wall socket
# state.n breaker point
# state.n fraction
# state.n have an effect or impact on
# state.n give an impression
# state.n take on an appearance or position
# state.n desire, wish, plan, intend
# state.n physically grasp, position, or support something
# state.n stop or restrain something; keep something from being used
# state.n maintain one's state, position, or physical integrity
# state.n maintain an attitude, belief, or opinion
# state.n possess or control something, e.g., money, position of authority, honor
# state.n contain or accommodate
# state.n be relevant or applicable
# state.n conduct a social event
# state.n block or cover protectively (by grasping)
# state.n idioms
# state.n paid position
# state.n task
# state.n being at work
# state.n object being worked on
# state.n a difficulty
# state.n destruction
# state.n robbery
# state.n Biblical figure
# state.n Biblical book
# state.n computer program
# state.n clarify, make comprehensible, describe
# state.n be a reason, cause, or justification of
# state.n give an account or convey impression of
# state.n depict or represent something pictorially
# state.n trace the form or outline of
# state.n consequence
# state.n general impression
# state.n validity
# state.n theme
# state.n property
# state.n the process
# state.n the end product
# state.n the act of developing
# state.n spatial location or placement of something/someone
# state.n opinion, attitude, stance, point of view, assumption
# state.n context, situation or circumstance
# state.n financial holdings of an investor, a financial market commitment
# state.n profession, job, function includes position in team sports)
# state.n rank in a sequence, standing in relation to others
# state.n a posture or arrangement, usually intentional
# state.n let, make possible, give permission
# state.n provide for, allot
# state.n to put together, assemble, concoct
# state.n to make ready, fit out
# state.n overseeing or directing
# state.n the people in charge
# state.n convey, show, state in some form
# state.n press out physically
# state.n to mail or post something via a rapid method
# state.n move forward, act at speed, pelt along
# state.n make someone or something hasten, induce or stimulate
# state.n run with a ball
# state.n meet or get to know members of fraternity or sorority
# state.n be
# state.n subsist, survive
# state.n give permission or privilege, bestow officially as judged due
# state.n willing to admit as truth
# state.n relinquish (physical) control
# state.n cause death, be fatal
# state.n cause great pain or anguish
# state.n eliminate
# state.n thwart
# state.n overwhelm
# state.n to strain oneself to the limit
# state.n cease operation of
# state.n hit with great force
# state.n drink down
# state.n put forward for consideration
# state.n intend
# state.n ask for hand in marriage
# state.n Geographic region
# state.n social sphere, scope of activity or interest
# state.n a circumscribed place with a specific characteristic
# state.n 2D bounded space in geometry
# state.n field of study, knowledge domain
# state.n recall to mind or keep in mind a piece of information
# state.n exercise or have power of memory
# state.n commemorate a special person, event, or occasion
# state.n consider, include
# state.n give greetings from
# state.n recover one's good manners after behaving badly
# state.n study, investigate, or analyze in detail
# state.n inspect something or somebody/look at
# state.n test someone by questioning; interrogate
# state.n an agent expresses or communicates a concept through words
# state.n to indicate something through a physical, non-verbal medium
# state.n express a supposition, occurs with the expression 'let us'
# state.n a written document's specific wording
# state.n physical act of articulating or pronouncing speech sounds
# state.n connect, link or unite separate things, either physically or abstractly
# state.n enlist or accept membership within some group or organization
# state.n participate with someone else in some event
# state.n accompany or meet up
# state.n discuss terms of agreement
# state.n navigate or manage something successfully
# state.n sell or transfer ownership
# state.n hold in a given state or situation
# state.n assert a proposition or belief
# state.n keep a reocrd
# state.n provide care and sustenance for someone
# state.n state
# state.n stipulation
# state.n consideration
# state.n not the control
# state.n accept something as true or probable, based on evidence and reasoning.
# state.n accept a doctrine, not necessarily nn the basis of reason or logic
# state.n 60 minutes
# state.n time of day
# state.n memorable period
# state.n distance
# state.n chair
# state.n head of a country
# state.n head of U.S.
# announce.v make known, declare
# announce.v name, identify
# announce.v foretell
# care.v consider as important enough for attention, concern or liking
# care.v tend or supervise somebody, provide protection and assistance
# care.v want, desire or perfer to do something
# ask.v inquire, seek an answer
# ask.v request or demand something from someone
# ask.v specify a price or value for something
# ask.v need, call for
# ask.v acting in a manner that results in specific consequences
# ask.v invite
# ask.v an argument that gives grounds or justification for a position
# ask.v action serving a protective function, often military
# ask.v a sports team in the role of preventing scoring by the opponent
# ask.v a legal team serving the client against the prosecution
# ask.v a structure to withstand attack
# ask.v organization of defenders, as military units
# ask.v business enterprises that build, develop military weaponry
# ask.v a federal department responsible for safeguarding national security
# ask.v available wealth or assets
# ask.v a seat of government or influence
# ask.v a letter represented in uppercase
# ask.v a book by Karl Marx
# ask.v uppermost part of a column
# ask.v residence change
# ask.v action
# ask.v Game:a turn
# ask.v other moves
# ask.v limit
# ask.v bottom
# ask.v foundation
# ask.v principle ingredient
# ask.v alkali
# ask.v bag
# ask.v station
# ask.v infrastructure
# ask.v stem
# ask.v radix
# ask.v transistor piece
# ask.v al-Qaeda
# ask.v a portion or percentage of a whole
# ask.v capital stock in a corporation
# ask.v a tool for tilling soil
# ask.v give, provide, donate something
# ask.v be a factor, play a role in
# ask.v induce, make happen
# ask.v process or set of rules that provides order and structure
# ask.v man-made system of (electrical/mechanical) closely interacting parts
# ask.v biological system of closely interacting parts
# ask.v loose collection of concrete objects which are linked through regularized interactions
# ask.v the powers that be
# ask.v strong desires and feelings
# ask.v a sample of matter in which substances in different phases are in equilibrium.
# ask.v repair,mend
# ask.v fasten,secure
# ask.v specify
# ask.v prepare, make, get ready
# ask.v take revenge on
# ask.v sterilize
# ask.v keep away, prevent from happening, or not do something
# ask.v LAW- annul, make void, make invalid
# ask.v relish, savor, delight in
# ask.v derive benefit from
# ask.v reveal something previously secret
# ask.v expose by removing a cover
# ask.v (cause to) change orientation or direction
# ask.v (cause to) undergo a transformation of substance, shape, or feature
# ask.v (cause to) undergo a change in attitude, emotion, belief, or custom
# ask.v send away or reject
# ask.v change the activation or arousal of
# ask.v prove, show to be, end up
# ask.v appear, discover, find
# ask.v produce, especially through commerce or business
# ask.v shape by rotating
# ask.v sprain, hurt by twisting
# ask.v deliver, hand over
# ask.v go to or get up from sleep
# ask.v (cause to) improve
# ask.v come or gather
# ask.v idioms
# ask.v perceive by sight
# ask.v realize, visualize or understand mentally (or through imagination)
# ask.v witness, observe, or experience
# ask.v verify, prove, check or insure by actively examining (evidence)
# ask.v take care of, take responsilibity over, keep up with
# ask.v meet or encounter on social or professional capacity
# ask.v match as in poker game
# ask.v SEE RED-become angry or upset
# ask.v SEE THE LIGHT-change or reform for the bettter
# ask.v SEE EYE TO EYE-be in agreement
# ask.v result in, tend to, cause, conduce
# ask.v travel in front of, be first, precede
# ask.v extend, connect, afford access to
# ask.v head, preside, direct
# ask.v guide
# ask.v pass, spend
# ask.v run, place
# ask.v origin or beginning
# ask.v an information reference, e.g. publication or an organization
# ask.v an informant
# ask.v the cause or instigation of something
# ask.v inspiration or muse
# ask.v repository or reservoir of something
# ask.v changing one thing for another
# ask.v a mutual expression of views
# ask.v marketplace
# ask.v telecommunications facility
# ask.v changing money, collectively
# ask.v a rally
# ask.v the physical expanse of the universe
# ask.v size or extent of an area or location, bounded or demarcated
# ask.v mathematical dimensionality, geometry
# ask.v small purposefully blank regions in documents
# ask.v unrestricted assertion of personal identity
# ask.v an amount or interval of time
# ask.v a notation, a single blank between letters
# ask.v block of typeset with no raised letters
# ask.v command
# ask.v order of magnitude
# ask.v lawfulness
# ask.v arrangement
# ask.v neatness
# ask.v purchase
# ask.v club
# ask.v taxonomic group
# ask.v greek style
# ask.v take something or someone away from somewhere
# ask.v murder
# ask.v maintain or preserve a particular condition, state, or activity
# ask.v retain ownership, access or title to something
# ask.v cause to stay in place; retain something in a particular place
# ask.v restrain, hold back, or prevent from doing something
# ask.v conform to, honor
# ask.v care for, sustain, look after
# ask.v observe, follow along, synchronize, track
# ask.v multi-word and verb particle constructions
# ask.v a system of interconnected social entities,e.g., people, organizations
# ask.v a broadcasting business, an enterprise that disseminates content via telecommunications equipment
# ask.v a physical system of interconnected components
# ask.v a mesh-like fabric or substance
# ask.v buy, obtain via finacncial transaction
# ask.v act, engage in, undertake, execute, cause, make
# ask.v fare, get along
# ask.v suffice or satisfy
# ask.v serve time (usually in prison)
# ask.v manage, carry on
# ask.v travel or go
# ask.v move, travel, proceed
# ask.v depart
# ask.v die, cease to function
# ask.v change to or continue in a certain state
# ask.v happen
# ask.v say or have the (sound) sequence of
# ask.v be on the point of; be intending to
# ask.v belong, fit, harmonize
# ask.v attend
# ask.v extend or stretch
# ask.v function, operate
# ask.v rifle, search through
# ask.v give support to
# ask.v miscellaneous idioms
# ask.v obtain, incur, get, encounter
# ask.v welcome, invite, accept
# ask.v stop, finish, terminate (A ends)
# ask.v bring to a halt, terminate (A causes B to end)
# ask.v be the end of, conclude (A is the event at the end of B)
# ask.v end up, wind up, finally be or do something
# ask.v have an initial point with some characteristic
# ask.v begin an event, action, or effect
# ask.v to cause to come into being
# ask.v (cause a machine to) begin to function or operate
# ask.v begin a journey, depart
# ask.v play in the starting lineup
# ask.v startle, jump
# ask.v portion
# ask.v our/his/my part
# ask.v function
# ask.v theatrical role
# ask.v share
# ask.v voice
# ask.v divide in hair
# ask.v try to do something
# ask.v the act of surmounting, climbing, descending
# ask.v experience, sense
# ask.v touch,grope
# ask.v find, conclude
# ask.v approximate, guess, reckon
# ask.v put, place, position
# ask.v go down, sink
# ask.v determine, fix at certain value
# ask.v prepare, arrange; create or organize for a particular purpose
# ask.v cause to assume a condition
# ask.v begin an activity, or cause one to begin
# ask.v fix firmly, solidify
# ask.v ensnare, frame, arrange through deceit
# ask.v dialect for SIT
# ask.v (cause to) attack
# ask.v hone
# ask.v reproduce,fructify
# ask.v move, travel, arrive
# ask.v occur, happen
# ask.v progress to a state
# ask.v be available, exist in a state
# ask.v originate from, issue from
# ask.v occur in a sequence, prioritized
# ask.v reach, extend to, total
# ask.v discover or think up
# ask.v be revealed
# ask.v experience orgasm
# ask.v idioms
# ask.v yield, create, make
# ask.v exhibit, release
# ask.v develop, acquire
# ask.v change for the better
# ask.v an opportunity
# ask.v events without apparent cause, random occurrence, luck
# ask.v risk, potential bad outcome
# ask.v a measure of the likelihood or probability of an event
# ask.v maintain or affirm that something is true
# ask.v demand, ask for, or take as one's due
# ask.v deserve, call for, or require
# ask.v cause death, as if by right
# ask.v increase
# ask.v lift, elevate, orient upwards
# ask.v express, activate
# ask.v collect, levy
# ask.v cultivate, nurture
# ask.v invoke, elicit, set off
# ask.v advance, better, promote
# ask.v construct, build
# ask.v end
# ask.v quality
# ask.v quantity
# ask.v moral principal
# ask.v duration of a musical note
# ask.v relative darkness
# ask.v consider, believe
# ask.v look
# ask.v concern, pertain
# ask.v finish an activity or process, either physical or abstract
# ask.v carry out an assigned task or duty
# ask.v make whole, add a missing part to a given whole
# ask.v establish the truth, validity, or authenticity of something
# ask.v turn out to be, show a particular result after a period of time
# ask.v show oneself to be competent or worthy
# ask.v LAW- establish as authentic or genuine
# ask.v COOKING- rise or gain volume in a warm place
# ask.v PRINTING ARTS- make a test impression
# ask.v cost
# ask.v pace, speed
# ask.v time to come
# ask.v verb tense
# ask.v commodities
# ask.v personal time to come
# ask.v use something to acquire goods; obtain through trade or transaction
# ask.v bribe, make payments to in exchange for benefits
# ask.v accept as true
# ask.v invest
# ask.v be killed; die
# ask.v take over ownership of
# ask.v stall, delay
# ask.v pledge or make a commitment
# ask.v give grounds for expectation
# ask.v a written list of particular things being offered
# ask.v a written notice that announces or advertises something
# ask.v a statute or draft not yet become law
# ask.v an itemized statement of money owed
# ask.v a printed note that is legal tender
# ask.v the mouth of a bird
# ask.v a long-handled saw
# ask.v brim of a hat that projects forward, visor
# ask.v the point of a ship anchor's fluke
# ask.v physically construct something, either directly or by implication
# ask.v develop, increase
# ask.v establish or create a complex process or abstract entity, according to a plan
# ask.v improve cleaning action of
# ask.v authorize, pass, clear
# ask.v judge or regard favorably
# ask.v power to give orders, official state of power
# ask.v assurance, confidence
# ask.v officials who have specific powers
# ask.v most knowledgable source, expert
# ask.v a government agency with specific power
# ask.v official permission to do something
# ask.v remember, cause to remember
# ask.v remove from circulation, defective products
# ask.v summon or order someone back
# ask.v restore or revive
# ask.v Medicines
# ask.v Narcotics
# ask.v Senses 1 and 2
# ask.v exert oneself in an activity
# ask.v perform, function, behave
# ask.v shape, form, handle
# ask.v proceed, move, position
# ask.v control, exploit, act upon
# ask.v operate
# ask.v ferment
# ask.v solve, figure out
# ask.v idioms
# ask.v a plan of action, approach
# ask.v Insurance policy
# ask.v an illegal lottery or numbers game
# ask.v an ability to control or influence
# ask.v entity that possesses ability to control or influence
# ask.v exerted physical force
# ask.v a mathematical measurement
# ask.v substitute, switch or supplant
# ask.v restore or return
# ask.v locate, discover, or encounter
# ask.v solve or calculate
# ask.v opine or believe
# ask.v accumulate a resource
# ask.v rule or pronounce, usually legal
# ask.v blame, criticize
# ask.v a general reference to any group of humans
# ask.v ordinary citizenry without special rank or status
# ask.v family line, relatives
# ask.v subordinate work associates
# ask.v specific ethnic groups
# ask.v state prosecution in a trial
# ask.v describe, account
# ask.v inform on
# ask.v be accountable to
# ask.v report out
# ask.v dot
# ask.v location
# ask.v meaning
# ask.v detail
# ask.v degree, level, stage
# ask.v sharp tip
# ask.v game scoring
# ask.v cape
# ask.v punctuation mark
# ask.v point
# ask.v gunpoint
# ask.v wall socket
# ask.v breaker point
# ask.v fraction
# ask.v have an effect or impact on
# ask.v give an impression
# ask.v take on an appearance or position
# ask.v desire, wish, plan, intend
# ask.v physically grasp, position, or support something
# ask.v stop or restrain something; keep something from being used
# ask.v maintain one's state, position, or physical integrity
# ask.v maintain an attitude, belief, or opinion
# ask.v possess or control something, e.g., money, position of authority, honor
# ask.v contain or accommodate
# ask.v be relevant or applicable
# ...
# point.n meaning
# point.n detail
# point.n degree, level, stage
# point.n sharp tip
# point.n game scoring
# point.n cape
# point.n punctuation mark
# point.n point
# point.n gunpoint
# point.n wall socket
# point.n breaker point
# point.n fraction
# affect.v have an effect or impact on
# affect.v give an impression
# affect.v take on an appearance or position
# hope.v desire, wish, plan, intend
# hold.v physically grasp, position, or support something
# hold.v stop or restrain something; keep something from being used
# hold.v maintain one's state, position, or physical integrity
# hold.v maintain an attitude, belief, or opinion
# hold.v possess or control something, e.g., money, position of authority, honor
# hold.v contain or accommodate
# hold.v be relevant or applicable
# hold.v conduct a social event
# hold.v block or cover protectively (by grasping)
# hold.v idioms
# job.n paid position
# job.n task
# job.n being at work
# job.n object being worked on
# job.n a difficulty
# job.n destruction
# job.n robbery
# job.n Biblical figure
# job.n Biblical book
# job.n computer program
# job.n clarify, make comprehensible, describe
# job.n be a reason, cause, or justification of
# job.n give an account or convey impression of
# job.n depict or represent something pictorially
# job.n trace the form or outline of
# job.n consequence
# job.n general impression
# job.n validity
# job.n theme
# job.n property
# job.n the process
# job.n the end product
# job.n the act of developing
# job.n spatial location or placement of something/someone
# job.n opinion, attitude, stance, point of view, assumption
# job.n context, situation or circumstance
# job.n financial holdings of an investor, a financial market commitment
# job.n profession, job, function includes position in team sports)
# job.n rank in a sequence, standing in relation to others
# job.n a posture or arrangement, usually intentional
# job.n let, make possible, give permission
# job.n provide for, allot
# job.n to put together, assemble, concoct
# job.n to make ready, fit out
# job.n overseeing or directing
# job.n the people in charge
# job.n convey, show, state in some form
# job.n press out physically
# job.n to mail or post something via a rapid method
# job.n move forward, act at speed, pelt along
# job.n make someone or something hasten, induce or stimulate
# job.n run with a ball
# job.n meet or get to know members of fraternity or sorority
# job.n be
# job.n subsist, survive
# job.n give permission or privilege, bestow officially as judged due
# job.n willing to admit as truth
# job.n relinquish (physical) control
# job.n cause death, be fatal
# job.n cause great pain or anguish
# job.n eliminate
# job.n thwart
# job.n overwhelm
# job.n to strain oneself to the limit
# job.n cease operation of
# job.n hit with great force
# job.n drink down
# job.n put forward for consideration
# job.n intend
# job.n ask for hand in marriage
# job.n Geographic region
# job.n social sphere, scope of activity or interest
# job.n a circumscribed place with a specific characteristic
# job.n 2D bounded space in geometry
# job.n field of study, knowledge domain
# job.n recall to mind or keep in mind a piece of information
# job.n exercise or have power of memory
# job.n commemorate a special person, event, or occasion
# job.n consider, include
# job.n give greetings from
# job.n recover one's good manners after behaving badly
# job.n study, investigate, or analyze in detail
# job.n inspect something or somebody/look at
# job.n test someone by questioning; interrogate
# job.n an agent expresses or communicates a concept through words
# job.n to indicate something through a physical, non-verbal medium
# job.n express a supposition, occurs with the expression 'let us'
# job.n a written document's specific wording
# job.n physical act of articulating or pronouncing speech sounds
# job.n connect, link or unite separate things, either physically or abstractly
# job.n enlist or accept membership within some group or organization
# job.n participate with someone else in some event
# job.n accompany or meet up
# job.n discuss terms of agreement
# job.n navigate or manage something successfully
# job.n sell or transfer ownership
# job.n hold in a given state or situation
# job.n assert a proposition or belief
# job.n keep a reocrd
# job.n provide care and sustenance for someone
# job.n state
# job.n stipulation
# job.n consideration
# job.n not the control
# job.n accept something as true or probable, based on evidence and reasoning.
# job.n accept a doctrine, not necessarily nn the basis of reason or logic
# job.n 60 minutes
# job.n time of day
# job.n memorable period
# job.n distance
# job.n chair
# job.n head of a country
# job.n head of U.S.
# explain.v clarify, make comprehensible, describe
# explain.v be a reason, cause, or justification of
# describe.v give an account or convey impression of
# describe.v depict or represent something pictorially
# describe.v trace the form or outline of
# effect.n consequence
# effect.n general impression
# effect.n validity
# effect.n theme
# effect.n property
# development.n the process
# development.n the end product
# development.n the act of developing
# position.n spatial location or placement of something/someone
# position.n opinion, attitude, stance, point of view, assumption
# position.n context, situation or circumstance
# position.n financial holdings of an investor, a financial market commitment
# position.n profession, job, function includes position in team sports)
# position.n rank in a sequence, standing in relation to others
# position.n a posture or arrangement, usually intentional
# allow.v let, make possible, give permission
# allow.v provide for, allot
# prepare.v to put together, assemble, concoct
# prepare.v to make ready, fit out
# management.n overseeing or directing
# management.n the people in charge
# express.v convey, show, state in some form
# express.v press out physically
# express.v to mail or post something via a rapid method
# rush.v move forward, act at speed, pelt along
# rush.v make someone or something hasten, induce or stimulate
# rush.v run with a ball
# rush.v meet or get to know members of fraternity or sorority
# rush.v be
# rush.v subsist, survive
# rush.v give permission or privilege, bestow officially as judged due
# rush.v willing to admit as truth
# rush.v relinquish (physical) control
# rush.v cause death, be fatal
# rush.v cause great pain or anguish
# rush.v eliminate
# rush.v thwart
# rush.v overwhelm
# rush.v to strain oneself to the limit
# rush.v cease operation of
# rush.v hit with great force
# rush.v drink down
# rush.v put forward for consideration
# rush.v intend
# rush.v ask for hand in marriage
# rush.v Geographic region
# rush.v social sphere, scope of activity or interest
# rush.v a circumscribed place with a specific characteristic
# rush.v 2D bounded space in geometry
# rush.v field of study, knowledge domain
# rush.v recall to mind or keep in mind a piece of information
# rush.v exercise or have power of memory
# rush.v commemorate a special person, event, or occasion
# rush.v consider, include
# rush.v give greetings from
# rush.v recover one's good manners after behaving badly
# rush.v study, investigate, or analyze in detail
# rush.v inspect something or somebody/look at
# rush.v test someone by questioning; interrogate
# rush.v an agent expresses or communicates a concept through words
# rush.v to indicate something through a physical, non-verbal medium
# rush.v express a supposition, occurs with the expression 'let us'
# rush.v a written document's specific wording
# rush.v physical act of articulating or pronouncing speech sounds
# rush.v connect, link or unite separate things, either physically or abstractly
# rush.v enlist or accept membership within some group or organization
# rush.v participate with someone else in some event
# rush.v accompany or meet up
# rush.v discuss terms of agreement
# rush.v navigate or manage something successfully
# rush.v sell or transfer ownership
# rush.v hold in a given state or situation
# rush.v assert a proposition or belief
# rush.v keep a reocrd
# rush.v provide care and sustenance for someone
# rush.v state
# rush.v stipulation
# rush.v consideration
# rush.v not the control
# rush.v accept something as true or probable, based on evidence and reasoning.
# rush.v accept a doctrine, not necessarily nn the basis of reason or logic
# rush.v 60 minutes
# rush.v time of day
# rush.v memorable period
# rush.v distance
# rush.v chair
# rush.v head of a country
# rush.v head of U.S.
# exist.v be
# exist.v subsist, survive
# grant.v give permission or privilege, bestow officially as judged due
# grant.v willing to admit as truth
# grant.v relinquish (physical) control
# kill.v cause death, be fatal
# kill.v cause great pain or anguish
# kill.v eliminate
# kill.v thwart
# kill.v overwhelm
# kill.v to strain oneself to the limit
# kill.v cease operation of
# kill.v hit with great force
# kill.v drink down
# propose.v put forward for consideration
# propose.v intend
# propose.v ask for hand in marriage
# area.n Geographic region
# area.n social sphere, scope of activity or interest
# area.n a circumscribed place with a specific characteristic
# area.n 2D bounded space in geometry
# area.n field of study, knowledge domain
# remember.v recall to mind or keep in mind a piece of information
# remember.v exercise or have power of memory
# remember.v commemorate a special person, event, or occasion
# remember.v consider, include
# remember.v give greetings from
# remember.v recover one's good manners after behaving badly
# remember.v study, investigate, or analyze in detail
# remember.v inspect something or somebody/look at
# remember.v test someone by questioning; interrogate
# remember.v an agent expresses or communicates a concept through words
# remember.v to indicate something through a physical, non-verbal medium
# remember.v express a supposition, occurs with the expression 'let us'
# remember.v a written document's specific wording
# remember.v physical act of articulating or pronouncing speech sounds
# remember.v connect, link or unite separate things, either physically or abstractly
# remember.v enlist or accept membership within some group or organization
# remember.v participate with someone else in some event
# remember.v accompany or meet up
# remember.v discuss terms of agreement
# remember.v navigate or manage something successfully
# remember.v sell or transfer ownership
# remember.v hold in a given state or situation
# remember.v assert a proposition or belief
# remember.v keep a reocrd
# remember.v provide care and sustenance for someone
# remember.v state
# remember.v stipulation
# remember.v consideration
# remember.v not the control
# remember.v accept something as true or probable, based on evidence and reasoning.
# remember.v accept a doctrine, not necessarily nn the basis of reason or logic
# remember.v 60 minutes
# remember.v time of day
# remember.v memorable period
# remember.v distance
# remember.v chair
# remember.v head of a country
# remember.v head of U.S.
# examine.v study, investigate, or analyze in detail
# examine.v inspect something or somebody/look at
# examine.v test someone by questioning; interrogate
# say.v an agent expresses or communicates a concept through words
# say.v to indicate something through a physical, non-verbal medium
# say.v express a supposition, occurs with the expression 'let us'
# say.v a written document's specific wording
# say.v physical act of articulating or pronouncing speech sounds
# join.v connect, link or unite separate things, either physically or abstractly
# join.v enlist or accept membership within some group or organization
# join.v participate with someone else in some event
# join.v accompany or meet up
# negotiate.v discuss terms of agreement
# negotiate.v navigate or manage something successfully
# negotiate.v sell or transfer ownership
# maintain.v hold in a given state or situation
# maintain.v assert a proposition or belief
# maintain.v keep a reocrd
# maintain.v provide care and sustenance for someone
# condition.n state
# condition.n stipulation
# condition.n consideration
# condition.n not the control
# believe.v accept something as true or probable, based on evidence and reasoning.
# believe.v accept a doctrine, not necessarily nn the basis of reason or logic
# hour.n 60 minutes
# hour.n time of day
# hour.n memorable period
# hour.n distance
# president.n chair
# president.n head of a country
# president.n head of U.S.
# {'begin.v': ['start, have an initial point ', 'initiate an undertaking', 'make a locution, speak', 'partially attain', 'express feelings of pain, dissatisfaction, or resentment', 'make formal, legal accusation or bring charge', 'a building, or group of buildings, for industrial activity', 'living photosynthesizing organism', 'a contrivance or stratagem', 'must have, demand', 'must do something', 'an employee who delivers things, e.g. mail', 'a bearer who bodily conveys something, e.g, supplies', 'a vehicle or vessel that transports cargo or passengers', 'a naval warship bearing aircraft', 'a device to hold or transport items', 'a transportation business', 'an insurance business', 'a telecommunications business', 'an organism carrying a masked recessive gene', 'an organism carrying a pathogen, but not showing symptoms', 'inactive chemical substance acting as a catalyst', 'a particle holding, or capable of holding, electric charge', 'a modulated radio wave that can convey a signal', 'happen or take place', 'come to mind', 'exist, be present', 'happen or go together', 'nation', 'one of the constituent administrative districts of a nation', 'the conditions and attributes that define something', 'U.S. Dept. of State', 'make known, declare', 'name, identify', 'foretell', 'consider as important enough for attention, concern or liking', 'tend or supervise somebody, provide protection and assistance', 'want, desire or perfer to do something', 'inquire, seek an answer', 'request or demand something from someone', 'specify a price or value for something', 'need, call for', 'acting in a manner that results in specific consequences', 'invite', 'an argument that gives grounds or justification for a position', 'action serving a protective function, often military', 'a sports team in the role of preventing scoring by the opponent', 'a legal team serving the client against the prosecution', 'a structure to withstand attack', 'organization of defenders, as military units', 'business enterprises that build, develop military weaponry', 'a federal department responsible for safeguarding national security', 'available wealth or assets', 'a seat of government or influence', 'a letter represented in uppercase', 'a book by Karl Marx', 'uppermost part of a column', 'residence change', 'action', 'Game:a turn', 'other moves', 'limit', 'bottom', 'foundation', 'principle ingredient', 'alkali', 'bag', 'station', 'infrastructure', 'stem', 'radix', 'transistor piece', 'al-Qaeda', 'a portion or percentage of a whole', 'capital stock in a corporation', 'a tool for tilling soil', 'give, provide, donate something', 'be a factor, play a role in', 'induce, make happen', 'process or set of rules that provides order and structure', 'man-made system of (electrical/mechanical) closely interacting parts', 'biological system of closely interacting parts', 'loose collection of concrete objects which are linked through regularized interactions', 'the powers that be', 'strong desires and feelings', 'a sample of matter in which substances in different phases are in equilibrium.', 'repair,mend', 'fasten,secure', 'specify', 'prepare, make, get ready', 'take revenge on', 'sterilize', 'keep away, prevent from happening, or not do something', 'LAW- annul, make void, make invalid', 'relish, savor, delight in', 'derive benefit from', 'reveal something previously secret', 'expose by removing a cover', '(cause to) change orientation or direction', '(cause to) undergo a transformation of substance, shape, or feature', '(cause to) undergo a change in attitude, emotion, belief, or custom', 'send away or reject', 'change the activation or arousal of', 'prove, show to be, end up', 'appear, discover, find', 'produce, especially through commerce or business', 'shape by rotating', 'sprain, hurt by twisting', 'deliver, hand over', 'go to or get up from sleep', '(cause to) improve', 'come or gather', 'idioms', 'perceive by sight', 'realize, visualize or understand mentally (or through imaginat ...

# %%
infile1 = open("P:/Fall 18/Text Mining/Homework02/dictionary.xml","r")
train1 = open("P:/Fall 18/Text Mining/Homework02/train.data","r")
test1 = open("P:/Fall 18/Text Mining/Homework02/test.data","r")
validate1 = open("P:/Fall 18/Text Mining/Homework02/validate.data","r")

# %%
# Cleaning and processing
# Removing stop words
# Stemming and lemmatizing wil be done here

def clean_up(inp):
    
    ad_s=('i','my','me','mine','said','said','also','say','u.s.','nt','much','one','m.r','m.r.','mr.','mrs.','mrs','have') # creating custom stop words to be removed
    stopwords=nltk.corpus.stopwords.words('english')
    stopwords.append(ad_s)
    
    clean_dt=[]
    for f in str(inp).split(" "):
        w=re.sub(r'[^a-zA-Z\.\%%]','', f)
        w=w.lower()
        if w not in stopwords:
            if w != '':
                w = porter.stem(w)
                clean_dt.append(w)
    return clean_dt

# %%
# Reading list with all the training data
nw_train1=train1
train_List1 = [line.split('\n') for line in nw_train1]
print(train_List1)
# Out:
# <_io.TextIOWrapper name='P:/Fall 18/Text Mining/Homework02/train.data' mode='r' encoding='cp1252'>

# %%
soup = BeautifulSoup(infile1,'xml')

# %%
dict_gloss=dict()
for i in soup.find_all("lexelt"): 
    x=(i.get('item'))
    for j in i.find_all("sense"):  
        z = j.get('id')
        y=(j.get('gloss'))
        dict_gloss.setdefault(x,[]).append(y)

# %%
# get data list of words in dataframe
dfp = pd.DataFrame(columns=['wrd','only_wrd','sense'])
cnt=0
for each_entry in train_List1:
    w,ws=get_trainWord(each_entry) 
    given=w+"."+str(ws)
    
    dfp.loc[cnt]=given,w,ws
    cnt+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5d36cea51bdd> in <module>
#       3 cnt=0
#       4 for each_entry in train_List1:
# ----> 5     w,ws=get_trainWord(each_entry)
#       6     given=w+"."+str(ws)
#       7
#
# NameError: name 'get_trainWord' is not defined

# %%
temp=(dfp[['wrd','only_wrd']].groupby(['wrd','only_wrd'])['only_wrd'].count().reset_index(name='wordSense_count'))
temp_sens=pd.DataFrame(temp)
temp_sens
# Out:
#                wrd     only_wrd  wrdSense_count
# 0       affect.v.1     affect.v              45
# 1        allow.v.1      allow.v              98
# 2        allow.v.2      allow.v              10
# 3     announce.v.1   announce.v              87
# 4     announce.v.2   announce.v               1
# 5      approve.v.1    approve.v              50
# 6      approve.v.2    approve.v               3
# 7         area.n.1       area.n             240
# 8         area.n.2       area.n              76
# 9         area.n.3       area.n              10
# 10         ask.v.1        ask.v             226
# 11         ask.v.2        ask.v             112
# 12         ask.v.3        ask.v               4
# 13         ask.v.4        ask.v               1
# 14         ask.v.5        ask.v               2
# 15         ask.v.6        ask.v               3
# 16     attempt.v.1    attempt.v              40
# 17   authority.n.1  authority.n              39
# 18   authority.n.3  authority.n              46
# 19   authority.n.4  authority.n               1
# 20   authority.n.5  authority.n               4
# 21       avoid.v.1      avoid.v              55
# 22        base.n.1       base.n              23
# 23        base.n.2       base.n               1
# 24        base.n.3       base.n              38
# 25        base.n.6       base.n               7
# 26        base.n.7       base.n              23
# 27       begin.v.1      begin.v              69
# 28       begin.v.2      begin.v              42
# 29       begin.v.3      begin.v               1
# ..             ...          ...             ...
# 330      state.n.2      state.n             513
# 331      state.n.3      state.n              24
# 332     system.n.1     system.n             130
# 333     system.n.2     system.n             250
# 334     system.n.3     system.n               2
# 335     system.n.4     system.n              66
# 336     system.n.5     system.n               2
# 337       turn.v.1       turn.v             179
# 338      turn.v.11       turn.v               8
# 339      turn.v.12       turn.v               1
# 340      turn.v.13       turn.v               3
# 341      turn.v.14       turn.v               1
# 342      turn.v.15       turn.v              18
# 343       turn.v.2       turn.v              45
# 344       turn.v.3       turn.v              13
# 345       turn.v.4       turn.v              18
# 346       turn.v.5       turn.v              18
# 347       turn.v.6       turn.v              32
# 348       turn.v.7       turn.v               3
# 349       turn.v.8       turn.v               1
# 350      value.n.1      value.n              24
# 351      value.n.2      value.n             299
# 352      value.n.3      value.n              12
# 353       work.v.1       work.v             149
# 354       work.v.2       work.v              49
# 355       work.v.3       work.v               3
# 356       work.v.4       work.v               4
# 357       work.v.5       work.v               2
# 358       work.v.8       work.v              14
# 359       work.v.9       work.v               9
#
# [360 rows x 3 columns]

# %%
temp2=(dfp[['only_wrd']].groupby(['only_wrd'])['only_wrd'].count().reset_index(name='wrd_count'))
temp_wrd=pd.DataFrame(temp2)
temp_wrd
# Out:
#          only_wrd  wrd_count
# 0        affect.v         45
# 1         allow.v        108
# 2      announce.v         88
# 3       approve.v         53
# 4          area.n        326
# 5           ask.v        348
# 6       attempt.v         40
# 7     authority.n         90
# 8         avoid.v         55
# 9          base.n         92
# 10        begin.v        114
# 11      believe.v        202
# 12         bill.n        404
# 13        build.v        119
# 14          buy.v        164
# 15      capital.n        278
# 16         care.v         69
# 17      carrier.n        111
# 18        cause.v         73
# 19       chance.n         91
# 20        claim.v         54
# 21         come.v        186
# 22     complain.v         32
# 23     complete.v         42
# 24    condition.n        132
# 25   contribute.v         35
# 26      defense.n        120
# 27     describe.v         57
# 28  development.n        180
# 29     disclose.v         55
# ..            ...        ...
# 70        power.n        251
# 71      prepare.v         54
# 72    president.n        879
# 73      produce.v        115
# 74      promise.v         50
# 75      propose.v         34
# 76        prove.v         49
# 77     purchase.v         35
# 78        raise.v        147
# 79         rate.n       1009
# 80       recall.v         49
# 81      receive.v        136
# 82       regard.v         40
# 83     remember.v        121
# 84       remove.v         47
# 85      replace.v         46
# 86       report.v        128
# 87         rush.v         28
# 88          say.v       2161
# 89          see.v        158
# 90          set.v        174
# 91        share.n       2536
# 92       source.n        152
# 93        space.n         67
# 94        start.v        214
# 95        state.n        617
# 96       system.n        450
# 97         turn.v        340
# 98        value.n        335
# 99         work.v        230
#
# [100 rows x 2 columns]

# %%
for i in range(0,len(temp_sens)):
    wrd_s=temp_sens.iloc[i][0]
    #print("Sense: ",wrd_s)
    wrd=temp_sens.iloc[i][1]
    #print("Wrd: ",wrd)
    numer=temp_sens.iloc[i][2]
    #print("senseCount: ",numer)
    deno=temp_wrd.loc[temp_wrd['only_wrd']==wrd]['wrd_count'].values[0]
    #print("wrdCount: ",deno)
    pr=numer/deno
    #print(pr)
    temp_prob.loc[i]=wrd_s,pr
temp_prob
# Out:
#         word_sense        prob
# 0       affect.v.1           1
# 1        allow.v.1    0.907407
# 2        allow.v.2   0.0925926
# 3     announce.v.1    0.988636
# 4     announce.v.2   0.0113636
# 5      approve.v.1    0.943396
# 6      approve.v.2   0.0566038
# 7         area.n.1    0.736196
# 8         area.n.2    0.233129
# 9         area.n.3   0.0306748
# 10         ask.v.1    0.649425
# 11         ask.v.2    0.321839
# 12         ask.v.3   0.0114943
# 13         ask.v.4  0.00287356
# 14         ask.v.5  0.00574713
# 15         ask.v.6  0.00862069
# 16     attempt.v.1           1
# 17   authority.n.1    0.433333
# 18   authority.n.3    0.511111
# 19   authority.n.4   0.0111111
# 20   authority.n.5   0.0444444
# 21       avoid.v.1           1
# 22        base.n.1        0.25
# 23        base.n.2   0.0108696
# 24        base.n.3    0.413043
# 25        base.n.6    0.076087
# 26        base.n.7        0.25
# 27       begin.v.1    0.605263
# 28       begin.v.2    0.368421
# 29       begin.v.3  0.00877193
# ..             ...         ...
# 330      state.n.2    0.831442
# 331      state.n.3   0.0388979
# 332     system.n.1    0.288889
# 333     system.n.2    0.555556
# 334     system.n.3  0.00444444
# 335     system.n.4    0.146667
# 336     system.n.5  0.00444444
# 337       turn.v.1    0.526471
# 338      turn.v.11   0.0235294
# 339      turn.v.12  0.00294118
# 340      turn.v.13  0.00882353
# 341      turn.v.14  0.00294118
# 342      turn.v.15   0.0529412
# 343       turn.v.2    0.132353
# 344       turn.v.3   0.0382353
# 345       turn.v.4   0.0529412
# 346       turn.v.5   0.0529412
# 347       turn.v.6   0.0941176
# 348       turn.v.7  0.00882353
# 349       turn.v.8  0.00294118
# 350      value.n.1   0.0716418
# 351      value.n.2    0.892537
# 352      value.n.3   0.0358209
# 353       work.v.1    0.647826
# 354       work.v.2    0.213043
# 355       work.v.3   0.0130435
# 356       work.v.4   0.0173913
# 357       work.v.5  0.00869565
# 358       work.v.8   0.0608696
# 359       work.v.9   0.0391304
#
# [360 rows x 2 columns]

# %%
def get_featureWord(word,sent):
    #print("get_featureWord : ",word,"\n",sent)
    wrd_array=[]
    if(word in sent):
        wr_index=sent.index(word)

        iter_lst=[wr_index-2,wr_index-3,wr_index-4,wr_index-5,wr_index-6,wr_index+2,wr_index+3,wr_index+4,wr_index+5,wr_index+6]
        not_needed=['.','%','%%','mr.','u.s.','u.s.','one','said','would','like']
        for k in iter_lst:

            try:
                gotdata = sent[k]
                if (gotdata not in not_needed) and len(gotdata)>3:
                    wrd_array.append(gotdata)
            except IndexError:
                #gotdata = 'null'
                pass
    return wrd_array

# %%
#test
get_featureWord('allow',al[1])
# Out:
# ['bush', 'arrest', 'demonstr', 'take', 'effect', 'without', 'signatur', 'went']

# %%
import re
#funtion to know the word of training, to look in dictionary
# Pass unclean string
def get_InputWord(inpList):
    word_pos=re.sub(r'[^a-zA-Z\.]','',(str((inpList)).split("|"))[0])
    word_sense=re.sub(r'[^\d]','',(str((inpList)).split("|"))[1])
    word_context=re.sub(r'[^a-zA-Z\.]','',(str((cl)).split("."))[0])

    return word_pos,word_sense,word_context

# %%
wpos,ws,wc=get_InputWord(fst)
print(wpos,ws,wc)
# Out:
# affect.v 1 affect

# %%
# create dcitionary of training words
dict_train=dict()
for i in train_List1: 
    cln=clean_up(i)
    wpos,ws,wc=get_InputnWord(i)
    ky=wpos+"."+ws
    dict_train.setdefault(ky,[]).append(cln)

# %%
len(dict_train)
# Out:
# 360

# %%
# get fearue list of a word for all sentences in the data
def allFeatureList(ky):
    #print("allFeatureList : ",ky)
    ftr_lst=[]
    word=ky.split(".")[0]
    for j in range(0,len(dict_train[ky])):
        rel_dict=dict_train[ky][j]
        features = get_featureWord(word,rel_dict)
        for feature in features:
            if feature not in ftr_lst:
                ftr_lst.append(feature)
                
    return ftr_lst

# %%
allFeatureList('allow.v.1')

# %%
def getFeatureCount(ky):
    hm=0
   # print("getFeatureCount :" , ky)
    featuresHere=allFeatureList(ky)
    wrd=ky.split(".")[0]
    for w in featuresHere:
        vv=0
        for m in (dict_train[ky]):
            c=m.count(w)
            vv=vv+c
        df_test.loc[hm]=wrd,ky ,w, vv
        hm+=1 

    return df_test

# %%
df_test.iloc[0:0]
dd=getFeatureCount('affect.v.1')
#ddd=dd.set_index(['wrd','feature']).groupby('feature').nlargest(5).reset_index() 
((dd.sort_values('feature_count',ascending = False)).iloc[1:6]).reset_index(drop=True)
#ddd.iloc[1:6]

# %%
########### Execution step
# using the above function to get the count of feature word
###########
dfFeatureCount.iloc[0:0] # drop all rows from the data frame
df_test.iloc[0:0] # drop all rows from the data frame

df_test=pd.DataFrame(columns=['only_wrd','wrd_sense','feature','feature_count'])
dfFeatureCount=pd.DataFrame(columns=['only_wrd','wrd_sense','feature','feature_count'])

key_lst=list(dict_train.keys())

for l in range(0,len(key_lst)):
    ky=(key_lst[l])
    #print(ky)
    dd=getFeatureCount(ky)
    dd=((dd.sort_values('feature_count',ascending = False)).iloc[1:7])
    dfFeatureCount=dfFeatureCount.append(dd)

# %%
dfFeatureCount
# Out:
#      only_wrd   wrd_sense   feature feature_count
# 69     affect  affect.v.1      also            16
# 220    affect  affect.v.1    govern            14
# 45     affect  affect.v.1    market            13
# 62     affect  affect.v.1      hous            13
# 16     affect  affect.v.1      year            13
# 137    affect  affect.v.1   compani            10
# 69     affect  affect.v.1      also            16
# 220    affect  affect.v.1    govern            14
# 137    affect  affect.v.1   compani            10
# 191    affect  affect.v.1     stori             9
# 244    affect  affect.v.1     negro             9
# 228    affect  affect.v.1  southern             9
# 188     allow   allow.v.1   allow.v            98
# 128     allow   allow.v.1     trade            22
# 77      allow   allow.v.1      year            20
# 53      allow   allow.v.1    comput            19
# 76      allow   allow.v.1      also            19
# 143     allow   allow.v.1      hous            19
# 188     allow   allow.v.1   allow.v            98
# 128     allow   allow.v.1     trade            22
# 77      allow   allow.v.1      year            20
# 53      allow   allow.v.1    comput            19
# 76      allow   allow.v.1      also            19
# 143     allow   allow.v.1      hous            19
# 188     allow   allow.v.1   allow.v            98
# 128     allow   allow.v.1     trade            22
# 77      allow   allow.v.1      year            20
# 53      allow   allow.v.1    comput            19
# 76      allow   allow.v.1      also            19
# 143     allow   allow.v.1      hous            19
# ...       ...         ...       ...           ...
# 2308      say     say.v.1      hous           145
# 2300      say     say.v.1     point           124
# 2279      say     say.v.1    return           104
# 2492      say     say.v.1      east           102
# 2104      say     say.v.1    receiv            90
# 2151      say     say.v.1  ministri            80
# 2308      say     say.v.1      hous           145
# 2300      say     say.v.1     point           124
# 2279      say     say.v.1    return           104
# 2492      say     say.v.1      east           102
# 2104      say     say.v.1    receiv            90
# 2151      say     say.v.1  ministri            80
# 2308      say     say.v.1      hous           145
# 2300      say     say.v.1     point           124
# 2279      say     say.v.1    return           104
# 2492      say     say.v.1      east           102
# 2104      say     say.v.1    receiv            90
# 2151      say     say.v.1  ministri            80
# 2308      say     say.v.1      hous           145
# 2300      say     say.v.1     point           124
# 2279      say     say.v.1    return           104
# 2492      say     say.v.1      east           102
# 2104      say     say.v.1    receiv            90
# 2151      say     say.v.1  ministri            80
# 2308      say     say.v.1      hous           145
# 2300      say     say.v.1     point           124
# 2279      say     say.v.1    return           104
# 2492      say     say.v.1      east           102
# 2104      say     say.v.1    receiv            90
# 2151      say     say.v.1  ministri            80
#
# [2160 rows x 4 columns]

# %%
newD=dfFeatureCount.reset_index(drop=True)

comData=pd.DataFrame(columns=['wrd','wrd_sns','feature','feature_count','wrdSense_count','P(f|s)'])

for i in range(0,len(newD)):
    wrd_sense=newD['wrd_sense'][i] 
    only_wrd=newD['only_wrd'][i]
    ftr=newD['feature'][i]    
    ftr_count=newD['feature_count'][i]
    wrdSense_count=temp_sens[temp_sens['wrd']==wrd_sense]['wrdSense_count'].values[0]
    pr=ftr_count/wrdSense_count
    comData.loc[i]=only_wrd,wrd_sense,ftr,ftr_count,wrdSense_count,pr
#print (comData)

# %%
comData #
# Out:
#          wrd     wrd_sns   feature feature_count wrdSense_count    P(f|s)
# 0     affect  affect.v.1      also            16             45  0.355556
# 1     affect  affect.v.1    govern            14             45  0.311111
# 2     affect  affect.v.1    market            13             45  0.288889
# 3     affect  affect.v.1      hous            13             45  0.288889
# 4     affect  affect.v.1      year            13             45  0.288889
# 5     affect  affect.v.1   compani            10             45  0.222222
# 6     affect  affect.v.1      also            16             45  0.355556
# 7     affect  affect.v.1    govern            14             45  0.311111
# 8     affect  affect.v.1   compani            10             45  0.222222
# 9     affect  affect.v.1     stori             9             45  0.200000
# 10    affect  affect.v.1     negro             9             45  0.200000
# 11    affect  affect.v.1  southern             9             45  0.200000
# 12     allow   allow.v.1   allow.v            98             98  1.000000
# 13     allow   allow.v.1     trade            22             98  0.224490
# 14     allow   allow.v.1      year            20             98  0.204082
# 15     allow   allow.v.1    comput            19             98  0.193878
# 16     allow   allow.v.1      also            19             98  0.193878
# 17     allow   allow.v.1      hous            19             98  0.193878
# 18     allow   allow.v.1   allow.v            98             98  1.000000
# 19     allow   allow.v.1     trade            22             98  0.224490
# 20     allow   allow.v.1      year            20             98  0.204082
# 21     allow   allow.v.1    comput            19             98  0.193878
# 22     allow   allow.v.1      also            19             98  0.193878
# 23     allow   allow.v.1      hous            19             98  0.193878
# 24     allow   allow.v.1   allow.v            98             98  1.000000
# 25     allow   allow.v.1     trade            22             98  0.224490
# 26     allow   allow.v.1      year            20             98  0.204082
# 27     allow   allow.v.1    comput            19             98  0.193878
# 28     allow   allow.v.1      also            19             98  0.193878
# 29     allow   allow.v.1      hous            19             98  0.193878
# ...      ...         ...       ...           ...            ...       ...
# 2130     say     say.v.1      hous           145           2113  0.068623
# 2131     say     say.v.1     point           124           2113  0.058684
# 2132     say     say.v.1    return           104           2113  0.049219
# 2133     say     say.v.1      east           102           2113  0.048273
# 2134     say     say.v.1    receiv            90           2113  0.042593
# 2135     say     say.v.1  ministri            80           2113  0.037861
# 2136     say     say.v.1      hous           145           2113  0.068623
# 2137     say     say.v.1     point           124           2113  0.058684
# 2138     say     say.v.1    return           104           2113  0.049219
# 2139     say     say.v.1      east           102           2113  0.048273
# 2140     say     say.v.1    receiv            90           2113  0.042593
# 2141     say     say.v.1  ministri            80           2113  0.037861
# 2142     say     say.v.1      hous           145           2113  0.068623
# 2143     say     say.v.1     point           124           2113  0.058684
# 2144     say     say.v.1    return           104           2113  0.049219
# 2145     say     say.v.1      east           102           2113  0.048273
# 2146     say     say.v.1    receiv            90           2113  0.042593
# 2147     say     say.v.1  ministri            80           2113  0.037861
# 2148     say     say.v.1      hous           145           2113  0.068623
# 2149     say     say.v.1     point           124           2113  0.058684
# 2150     say     say.v.1    return           104           2113  0.049219
# 2151     say     say.v.1      east           102           2113  0.048273
# 2152     say     say.v.1    receiv            90           2113  0.042593
# 2153     say     say.v.1  ministri            80           2113  0.037861
# 2154     say     say.v.1      hous           145           2113  0.068623
# 2155     say     say.v.1     point           124           2113  0.058684
# 2156     say     say.v.1    return           104           2113  0.049219
# 2157     say     say.v.1      east           102           2113  0.048273
# 2158     say     say.v.1    receiv            90           2113  0.042593
# 2159     say     say.v.1  ministri            80           2113  0.037861
#
# [2160 rows x 6 columns]

# %%
from collections import Counter
dict_train['affect.v.1'][1]
dtSupervisedPredi=pd.DataFrame(columns=['Given','Predicted'])

key_lst=list(dict_train.keys())
sense=""
cnt=0

for l in range(0,len(key_lst)):
    
    ky=(key_lst[l])

    dtKey=dict_train[ky]
    wrd=ky.split(".")[0]
    
    #print('key-',ky)
    avlbl_ftr=list(comData[(comData['wrd']==wrd)]['feature'])
    
    for each in range(0,len(dtKey)):
        #print(each)
        
        toPredict_ftr=get_featureWord(wrd,dict_train[ky][each])
        #print("PredFtr",toPredict_ftr)
        #print("avlblFtr",avlbl_ftr)
        
        del pr_sens[:]
        pr_sens=[]
        net_pr=0
        
        #print('word-',wrd)

        for pr in toPredict_ftr:
            prob=0
            
            if pr in avlbl_ftr:               
                #select the max probability
                prob = max(comData[(comData['wrd']==wrd)& (comData['feature']==pr)]['P(f|s)'])

                #find sense for that probability and word
                sense = comData[(comData['wrd']==wrd)& (comData['feature']==pr)]['wrd_sns'].values[0]
                                
            if not sense:
                continue
            else:
                pr_sens.append(sense)

        if not pr_sens:
            pr_sens.append('<NotFound>')
            
        prediction,num_most_common=Counter(pr_sens).most_common(1)[0]
        dtSupervisedPredi.loc[cnt]=ky,prediction
        cnt +=1
        #print("Given: ",ky,"Predicted: ",prediction)

# %%
# Supervised Model
dtSupervisedPredi
# Out:
#             Given   Predicted
# 0      affect.v.1  <NotFound>
# 1      affect.v.1  affect.v.1
# 2      affect.v.1  affect.v.1
# 3      affect.v.1  affect.v.1
# 4      affect.v.1  affect.v.1
# 5      affect.v.1  affect.v.1
# 6      affect.v.1  affect.v.1
# 7      affect.v.1  affect.v.1
# 8      affect.v.1  affect.v.1
# 9      affect.v.1  affect.v.1
# 10     affect.v.1  affect.v.1
# 11     affect.v.1  affect.v.1
# 12     affect.v.1  affect.v.1
# 13     affect.v.1  affect.v.1
# 14     affect.v.1  affect.v.1
# 15     affect.v.1  affect.v.1
# 16     affect.v.1  affect.v.1
# 17     affect.v.1  affect.v.1
# 18     affect.v.1  affect.v.1
# 19     affect.v.1  affect.v.1
# 20     affect.v.1  affect.v.1
# 21     affect.v.1  affect.v.1
# 22     affect.v.1  affect.v.1
# 23     affect.v.1  affect.v.1
# 24     affect.v.1  affect.v.1
# 25     affect.v.1  affect.v.1
# 26     affect.v.1  affect.v.1
# 27     affect.v.1  affect.v.1
# 28     affect.v.1  affect.v.1
# 29     affect.v.1  affect.v.1
# ...           ...         ...
# 22251    work.v.8    work.v.1
# 22252    work.v.8    work.v.1
# 22253    work.v.8    work.v.1
# 22254    work.v.8    work.v.1
# 22255    work.v.8    work.v.1
# 22256    work.v.8    work.v.1
# 22257    work.v.8    work.v.1
# 22258    work.v.8    work.v.1
# 22259    work.v.8    work.v.1
# 22260    work.v.8    work.v.1
# 22261    work.v.8    work.v.1
# 22262    work.v.8    work.v.1
# 22263    work.v.9    work.v.1
# 22264    work.v.9    work.v.1
# 22265    work.v.9    work.v.1
# 22266    work.v.9    work.v.1
# 22267    work.v.9    work.v.1
# 22268    work.v.9    work.v.1
# 22269    work.v.9    work.v.1
# 22270    work.v.9    work.v.1
# 22271    work.v.9    work.v.1
# 22272    work.v.3    work.v.1
# 22273    work.v.3    work.v.1
# 22274    work.v.3  <NotFound>
# 22275    work.v.5    work.v.1
# 22276    work.v.5    work.v.1
# 22277    work.v.4    work.v.1
# 22278    work.v.4    work.v.1
# 22279    work.v.4    work.v.1
# 22280    work.v.4    work.v.1
#
# [22281 rows x 2 columns]

# %%
accuracies = {}

def accuracy(df):
    res = (df['Given'] == df['Predicted']).values
    return ((res==True).sum()/float(len(res))) * 100  

accuracies['SupervisedModel'] = accuracy(dtSupervisedPredi)

print("{" + "\n".join("{}: {}".format(k, v) for k, v in accuracies.items()) + "}")
# Out:
# {SupervisedModel: 44.64790628786859}
